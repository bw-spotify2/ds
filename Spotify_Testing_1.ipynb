# %% [markdown]
# <a href="https://colab.research.google.com/github/bw-spotify2/ds/blob/master/Spotify_Testing_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spotipy --upgrade

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time

# %%
client_id = ''
client_secret = ''
username = ''

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
def getTrackIDs(user, playlist_id):
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
    return ids

ids = getTrackIDs('mahoryu', '37i9dQZF1DX692WcMwL2yW')

# %%
def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']

  # features
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']

  track = [name, album, artist, release_date, length, popularity, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
  return track

# %%
# loop over track ids 
tracks = []
for i in range(len(ids)):
  time.sleep(.5)
  track = getTrackFeatures(ids[i])
  tracks.append(track)

# create dataset
df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
df.to_csv("spotify.csv", sep = ',')

# %%
# polar plots convert atributes into a visual
# go autoencoder reduce to 2 dimentions and use the euclidian distance between points smallest distance is the recomendations

# %%
df.head(20)
# Out:
#                                  name  ... time_signature
# 0                               Grace  ...              4
# 1                          Selflessly  ...              4
# 2                             The Ace  ...              4
# 3                             Groovly  ...              4
# 4                             Save As  ...              4
# 5                         Heliolingus  ...              4
# 6                            Recenseo  ...              4
# 7                        Fall for You  ...              4
# 8   Autumn Mournings to Winter Nights  ...              4
# 9                    Suburban Sunrise  ...              4
# 10                            Peepers  ...              4
# 11                Weeping Cherry Tree  ...              4
# 12                          No Dreams  ...              4
# 13                            Spectra  ...              4
# 14                        Farmingdale  ...              4
# ...

# %%
meta = sp.track(ids[0])
features = sp.audio_features(ids[0])
features
# Out:
# [{'acousticness': 0.431,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2YOLzRGMjNSgZ3KZimG2Rg',
#   'danceability': 0.72,
#   'duration_ms': 144049,
#   'energy': 0.407,
#   'id': '2YOLzRGMjNSgZ3KZimG2Rg',
#   'instrumentalness': 0.889,
#   'key': 6,
#   'liveness': 0.0994,
#   'loudness': -12.916,
#   'mode': 1,
#   'speechiness': 0.0664,
#   'tempo': 80.211,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2YOLzRGMjNSgZ3KZimG2Rg',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2YOLzRGMjNSgZ3KZimG2Rg',
#   'valence': 0.39}]
